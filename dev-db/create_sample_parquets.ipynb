# %% [markdown]
# # Create Sample Parquet Extracts
#
# - Pulls Space2Stats cross-sectional and SPI time-series samples for a small AOI (Kenya + Uganda)
# - Cleans the retrieved frames, trims to schema-aligned columns, and writes the cross-sectional and time-series parquet files for local seeding/tests

# %%
import geopandas as gpd
import pandas as pd
from space2stats_client import Space2StatsClient

client = Space2StatsClient()

# %% [markdown]
# ## Build Cross-Country AOI

# %%
iso3_list = ["KEN", "UGA"]

countries = []
for iso3 in iso3_list:
    gdf = client.fetch_admin_boundaries(iso3=iso3, adm="ADM0")
    countries.append(gdf)

aoi = gpd.GeoDataFrame(pd.concat(countries, ignore_index=True), crs="EPSG:4326")

# %%
aoi_union = aoi.dissolve().reset_index(drop=True)
aoi_union
# Out:
#                                             geometry  FID ISO_A3 ISO_A2 WB_A3  \
# 0  MULTIPOLYGON (((39.40774 -4.70525, 39.40465 -4...   42    KEN     KE   KEN
#
#   HASC_0  GAUL_0 WB_REGION     WB_STATUS SOVEREIGN  NAM_0  \
# 0     KE     133       AFR  Member State       KEN  Kenya
#
#                                GlobalID  Shape__Area  Shape__Length
# 0  edc9ac00-2ebc-4ed1-9996-509777c61847     47.32705      46.140605

# %% [markdown]
# # Cross-Sectional Sample Data

# %%
fields = client.get_fields()
fields
# Out:
# ['sum_built_area_m_2030',
#  'pop',
#  'pop_flood',
#  'pop_flood_pct',
#  'sum_pop_f_0_2020',
#  'sum_pop_f_10_2020',
#  'sum_pop_f_15_2020',
#  'sum_pop_f_1_2020',
#  'sum_pop_f_20_2020',
#  'sum_pop_f_25_2020',
#  'sum_pop_f_30_2020',
#  'sum_pop_f_35_2020',
#  'sum_pop_f_40_2020',
#  'sum_pop_f_45_2020',
#  'sum_pop_f_50_2020',
#  'sum_pop_f_55_2020',
#  'sum_pop_f_5_2020',
#  'sum_pop_f_60_2020',
#  'sum_pop_f_65_2020',
#  'sum_pop_f_70_2020',
#  'sum_pop_f_75_2020',
#  'sum_pop_f_80_2020',
#  'sum_pop_m_0_2020',
#  'sum_pop_m_10_2020',
#  'sum_pop_m_15_2020',
#  'sum_pop_m_1_2020',
#  'sum_pop_m_20_2020',
#  'sum_pop_m_25_2020',
#  'sum_pop_m_30_2020',
#  'sum_pop_m_35_2020',
#  'sum_pop_m_40_2020',
#  'sum_pop_m_45_2020',
#  'sum_pop_m_50_2020',
#  'sum_pop_m_55_2020',
#  'sum_pop_m_5_2020',
#  'sum_pop_m_60_2020',
#  'sum_pop_m_65_2020',
#  'sum_pop_m_70_2020',
#  'sum_pop_m_75_2020',
#  'sum_pop_m_80_2020',
#  'sum_pop_f_2020',
#  'sum_pop_m_2020',
#  'sum_pop_2020',
#  'sum_pop_m_2020_v2',
#  'sum_pop_f_2020_v2',
#  'sum_pop_2020_v2',
#  'ghs_11_count',
#  'ghs_12_count',
#  'ghs_13_count',
#  'ghs_21_count',
#  'ghs_22_count',
#  'ghs_23_count',
#  'ghs_30_count',
#  'ghs_total_count',
#  'ghs_11_pop',
#  'ghs_12_pop',
#  'ghs_13_pop',
#  'ghs_21_pop',
#  'ghs_22_pop',
#  'ghs_23_pop',
#  'ghs_30_pop',
#  'ghs_total_pop',
#  'sum_viirs_ntl_201201',
#  'sum_viirs_ntl_201202',
#  'sum_viirs_ntl_201203',
#  'sum_viirs_ntl_201204',
#  'sum_viirs_ntl_201205',
#  'sum_viirs_ntl_201206',
#  'sum_viirs_ntl_201207',
#  'sum_viirs_ntl_201208',
#  'sum_viirs_ntl_201209',
#  'sum_viirs_ntl_201210',
#  'sum_viirs_ntl_201211',
#  'sum_viirs_ntl_201212',
#  'sum_viirs_ntl_201301',
#  'sum_viirs_ntl_201302',
#  'sum_viirs_ntl_201303',
#  'sum_viirs_ntl_201304',
#  'sum_viirs_ntl_201305',
#  'sum_viirs_ntl_201306',
#  'sum_viirs_ntl_201307',
#  'sum_viirs_ntl_201308',
#  'sum_viirs_ntl_201309',
#  'sum_viirs_ntl_201310',
#  'sum_viirs_ntl_201311',
#  'sum_viirs_ntl_201312',
#  'sum_viirs_ntl_201501',
#  'sum_viirs_ntl_201502',
#  'sum_viirs_ntl_201503',
#  'sum_viirs_ntl_201504',
#  'sum_viirs_ntl_201505',
#  'sum_viirs_ntl_201506',
#  'sum_viirs_ntl_201507',
#  'sum_viirs_ntl_201508',
#  'sum_viirs_ntl_201509',
#  'sum_viirs_ntl_201510',
#  'sum_viirs_ntl_201511',
#  'sum_viirs_ntl_201512',
#  'sum_viirs_ntl_201601',
#  'sum_viirs_ntl_201602',
#  'sum_viirs_ntl_201603',
#  'sum_viirs_ntl_201604',
#  'sum_viirs_ntl_201605',
#  'sum_viirs_ntl_201606',
#  'sum_viirs_ntl_201607',
#  'sum_viirs_ntl_201608',
#  'sum_viirs_ntl_201609',
#  'sum_viirs_ntl_201610',
#  'sum_viirs_ntl_201611',
#  'sum_viirs_ntl_201612',
#  'sum_viirs_ntl_201701',
#  'sum_viirs_ntl_201702',
#  'sum_viirs_ntl_201703',
#  'sum_viirs_ntl_201704',
#  'sum_viirs_ntl_201705',
#  'sum_viirs_ntl_201706',
#  'sum_viirs_ntl_201707',
#  'sum_viirs_ntl_201708',
#  'sum_viirs_ntl_201709',
#  'sum_viirs_ntl_201710',
#  'sum_viirs_ntl_201711',
#  'sum_viirs_ntl_201712',
#  'sum_viirs_ntl_201801',
#  'sum_viirs_ntl_201802',
#  'sum_viirs_ntl_201803',
#  'sum_viirs_ntl_201804',
#  'sum_viirs_ntl_201805',
#  'sum_viirs_ntl_201806',
#  'sum_viirs_ntl_201807',
#  'sum_viirs_ntl_201808',
#  'sum_viirs_ntl_201809',
#  'sum_viirs_ntl_201810',
#  'sum_viirs_ntl_201811',
#  'sum_viirs_ntl_201812',
#  'sum_viirs_ntl_201901',
#  'sum_viirs_ntl_201902',
#  'sum_viirs_ntl_201903',
#  'sum_viirs_ntl_201904',
#  'sum_viirs_ntl_201905',
#  'sum_viirs_ntl_201906',
#  'sum_viirs_ntl_201907',
#  'sum_viirs_ntl_201908',
#  'sum_viirs_ntl_201909',
#  'sum_viirs_ntl_201910',
#  'sum_viirs_ntl_201911',
#  'sum_viirs_ntl_201912',
#  'sum_viirs_ntl_202001',
#  'sum_viirs_ntl_202002',
#  'sum_viirs_ntl_202003',
#  'sum_viirs_ntl_202004',
#  'sum_viirs_ntl_202005',
#  'sum_viirs_ntl_202006',
#  'sum_viirs_ntl_202007',
#  'sum_viirs_ntl_202008',
#  'sum_viirs_ntl_202009',
#  'sum_viirs_ntl_202010',
#  'sum_viirs_ntl_202011',
#  'sum_viirs_ntl_202012',
#  'sum_viirs_ntl_2012',
#  'sum_viirs_ntl_2013',
#  'sum_viirs_ntl_2014',
#  'sum_viirs_ntl_2015',
#  'sum_viirs_ntl_2016',
#  'sum_viirs_ntl_2017',
#  'sum_viirs_ntl_2018',
#  'sum_viirs_ntl_2019',
#  'sum_viirs_ntl_2020',
#  'sum_viirs_ntl_2021',
#  'sum_viirs_ntl_2022',
#  'sum_viirs_ntl_2023',
#  'sum_viirs_ntl_2024',
#  'sum_built_area_m_1975',
#  'sum_built_area_m_1980',
#  'sum_built_area_m_1985',
#  'sum_built_area_m_1990',
#  'sum_built_area_m_1995',
#  'sum_built_area_m_2000',
#  'sum_built_area_m_2005',
#  'sum_built_area_m_2010',
#  'sum_built_area_m_2015',
#  'sum_built_area_m_2020',
#  'sum_built_area_m_2025']

# %%
def chunked(seq, n):
    for i in range(0, len(seq), n):
        yield seq[i:i+n]


all_parts = []
first = True

for field_chunk in chunked(fields, 10):  # adjust chunk size as needed
    kwargs = dict(
        gdf=aoi_union,
        spatial_join_method="centroid",
        fields=field_chunk,
    )
    if first:
        kwargs["geometry"] = "polygon" 

    part = client.get_summary(**kwargs)
    all_parts.append(gpd.GeoDataFrame(part))
    first = False
# Out:
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...
# Fetching data for boundary 1 of 1...

# %%
# Merge chunks on hex id
hex_key = "hex_id"
summary = all_parts[0]
for part in all_parts[1:]:
    df = pd.DataFrame(part).drop(columns=[c for c in part.columns if c in summary.columns and c != hex_key])
    summary = summary.merge(df, on=hex_key, how="left")

# %% [markdown]
# ### Clean Cross-Sectional Columns

# %%
to_drop = list(aoi_union.columns) + ["index_gdf", "index_h3"]
summary_clean = summary.drop(columns = to_drop)
summary_clean.head()

# %%
summary_clean.to_parquet("space2stats_sample_cs.parquet", index=False)

# %% [markdown]
# # Timeseries Sample Data

# %%
fields = client.get_timeseries_fields()
fields
# Out:
# ['spi']

# %%
aoi = client.fetch_admin_boundaries(iso3="KEN", adm="ADM0")

# %%
years = range(2015, 2021)  # 2015–2020 inclusive
dfs = []

for idx, country in enumerate(countries[:2]):
    for year in years:
        start = f"{year}-01-01"
        end = f"{year}-12-31"

        ts = client.get_timeseries(
            gdf=country,
            spatial_join_method="centroid",
            fields=["spi"],
            start_date=start,
            end_date=end,
            verbose=False,
        )

        if not ts.empty:
            ts["country_idx"] = idx
            ts["year"] = year
            dfs.append(ts)

result = pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()
result
# Out:
#          FID ISO_A3 ISO_A2 WB_A3 HASC_0  GAUL_0 WB_REGION     WB_STATUS  \
# 0         42    KEN     KE   KEN     KE     133       AFR  Member State
# 1         42    KEN     KE   KEN     KE     133       AFR  Member State
# 2         42    KEN     KE   KEN     KE     133       AFR  Member State
# 3         42    KEN     KE   KEN     KE     133       AFR  Member State
# 4         42    KEN     KE   KEN     KE     133       AFR  Member State
# ...      ...    ...    ...   ...    ...     ...       ...           ...
# 1542235   53    UGA     UG   UGA     UG     253       AFR  Member State
# 1542236   53    UGA     UG   UGA     UG     253       AFR  Member State
# 1542237   53    UGA     UG   UGA     UG     253       AFR  Member State
# 1542238   53    UGA     UG   UGA     UG     253       AFR  Member State
# 1542239   53    UGA     UG   UGA     UG     253       AFR  Member State
#
#         SOVEREIGN   NAM_0                              GlobalID  Shape__Area  \
# 0             KEN   Kenya  edc9ac00-2ebc-4ed1-9996-509777c61847    47.327050
# 1             KEN   Kenya  edc9ac00-2ebc-4ed1-9996-509777c61847    47.327050
# 2             KEN   Kenya  edc9ac00-2ebc-4ed1-9996-509777c61847    47.327050
# 3             KEN   Kenya  edc9ac00-2ebc-4ed1-9996-509777c61847    47.327050
# 4             KEN   Kenya  edc9ac00-2ebc-4ed1-9996-509777c61847    47.327050
# ...           ...     ...                                   ...          ...
# 1542235       UGA  Uganda  5442b7f4-c3e2-4f7c-bbe5-e9d6b1505cc3    19.617091
# 1542236       UGA  Uganda  5442b7f4-c3e2-4f7c-bbe5-e9d6b1505cc3    19.617091
# 1542237       UGA  Uganda  5442b7f4-c3e2-4f7c-bbe5-e9d6b1505cc3    19.617091
# 1542238       UGA  Uganda  5442b7f4-c3e2-4f7c-bbe5-e9d6b1505cc3    19.617091
# 1542239       UGA  Uganda  5442b7f4-c3e2-4f7c-bbe5-e9d6b1505cc3    19.617091
#
#          Shape__Length           hex_id                       date       spi  \
# 0            46.140605  866a58007ffffff  2015-01-01T00:00:00+00:00  0.677105
# 1            46.140605  866a58007ffffff  2015-02-01T00:00:00+00:00  0.482942
# 2            46.140605  866a58007ffffff  2015-03-01T00:00:00+00:00 -0.269795
# 3            46.140605  866a58007ffffff  2015-04-01T00:00:00+00:00  0.067042
# 4            46.140605  866a58007ffffff  2015-05-01T00:00:00+00:00  0.049126
# ...                ...              ...                        ...       ...
# 1542235      24.311077  867a4db6fffffff  2020-08-01T00:00:00+00:00  2.018657
# 1542236      24.311077  867a4db6fffffff  2020-09-01T00:00:00+00:00  1.359646
# 1542237      24.311077  867a4db6fffffff  2020-10-01T00:00:00+00:00  0.662396
# 1542238      24.311077  867a4db6fffffff  2020-11-01T00:00:00+00:00  1.424782
# 1542239      24.311077  867a4db6fffffff  2020-12-01T00:00:00+00:00  1.230841
#
#          area_id  country_idx  year
# 0              0            0  2015
# 1              0            0  2015
# 2              0            0  2015
# 3              0            0  2015
# 4              0            0  2015
# ...          ...          ...   ...
# 1542235        0            1  2020
# 1542236        0            1  2020
# 1542237        0            1  2020
# 1542238        0            1  2020
# 1542239        0            1  2020
#
# [1542240 rows x 19 columns]

# %%
needed_cols = ["hex_id", "date", "spi"]
result = result[needed_cols].copy()
result
# Out:
#                   hex_id                       date       spi
# 0        866a58007ffffff  2015-01-01T00:00:00+00:00  0.677105
# 1        866a58007ffffff  2015-02-01T00:00:00+00:00  0.482942
# 2        866a58007ffffff  2015-03-01T00:00:00+00:00 -0.269795
# 3        866a58007ffffff  2015-04-01T00:00:00+00:00  0.067042
# 4        866a58007ffffff  2015-05-01T00:00:00+00:00  0.049126
# ...                  ...                        ...       ...
# 1542235  867a4db6fffffff  2020-08-01T00:00:00+00:00  2.018657
# 1542236  867a4db6fffffff  2020-09-01T00:00:00+00:00  1.359646
# 1542237  867a4db6fffffff  2020-10-01T00:00:00+00:00  0.662396
# 1542238  867a4db6fffffff  2020-11-01T00:00:00+00:00  1.424782
# 1542239  867a4db6fffffff  2020-12-01T00:00:00+00:00  1.230841
#
# [1542240 rows x 3 columns]

# %%
result.to_parquet("space2stats_sample_ts.parquet", index=False)
