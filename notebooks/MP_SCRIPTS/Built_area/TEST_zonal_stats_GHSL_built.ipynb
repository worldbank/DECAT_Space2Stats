# %% [markdown]
# # Inspect Generated Zonal Stats
# This notebook will run through a checks to see if the generated h3 zonal stats have been calculated correctly. This will include checking at the following steps:
#
# 1. H1 CSV files on S3
# 2. Aggregated parquet files on S3
# 3. S2S database

# %%
import os, sys, time
import requests
import json
import h3

import geopandas as gpd
import pandas as pd
import folium as flm

from dotenv import load_dotenv
from geojson_pydantic import Feature, Polygon
from lonboard import Map, ScatterplotLayer
from shapely import from_geojson, Polygon
from space2stats import StatsTable
from shapely.geometry import shape, Point, Polygon
from typing import Dict

sys.path.append(r"C:\WBG\Work\Code\GOSTrocks\src")
import GOSTrocks.rasterMisc as rMisc

sys.path.append("../../src")
import global_zonal
import h3_helper

def tPrint(s):
    """prints the time along with the message"""
    print("%s\t%s" % (time.strftime("%H:%M:%S"), s))

# %%
# Define input variables
iso3 = 'KEN'
ADM = "ADM0"
csv_folder = 'C:/WBG/Work/S2S/data/GHSL/'
csv_base = '{h1}/ghsl_built_m_E{year}.csv'

# Fetch the admin boundaries and convert to geojson
def fetch_admin_boundaries(iso3: str, adm: str) -> gpd.GeoDataFrame:
    """Fetch administrative boundaries from GeoBoundaries API."""
    url = f"https://www.geoboundaries.org/api/current/gbOpen/{iso3}/{adm}/"
    res = requests.get(url, verify=False).json()
    return gpd.read_file(res["gjDownloadURL"])

adm_boundaries = fetch_admin_boundaries(iso3, ADM)
geojson_str = adm_boundaries.to_json()
adm_geojson = json.loads(geojson_str)
adm_features = adm_geojson["features"]
feature = adm_features[0]
# Out:
# c:\wbg\Anaconda3\envs\s2s\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.geoboundaries.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# loop through all the h1_cells and years and see if there are any actual results
for root, folders, files in os.walk(csv_folder):
    for f in files:
        if f.endswith(".csv"):
            cur_path = os.path.join(root, f)
            h1 = os.path.basename(root)
            year = f.split("_")[-1][1:5]
            cur_d = pd.read_csv(cur_path, index_col=0)
            max_val = cur_d.max(skipna=True)[:4].max(skipna=True)
            if max_val > 0:
                break
            else:
                print(f"no data for {h1} {year}")
# Out:
# no data for  1975
# no data for 8001fffffffffff 1975
# no data for 8001fffffffffff 1980
# no data for 8001fffffffffff 1985
# no data for 8001fffffffffff 1990
# no data for 8001fffffffffff 1995
# no data for 8001fffffffffff 2000
# no data for 8001fffffffffff 2005
# no data for 8001fffffffffff 2010
# no data for 8001fffffffffff 2015
# no data for 8001fffffffffff 2020
# no data for 8001fffffffffff 2025
# no data for 8003fffffffffff 1975
# no data for 8003fffffffffff 1980
# no data for 8003fffffffffff 1985
# no data for 8003fffffffffff 1990
# no data for 8003fffffffffff 1995
# no data for 8003fffffffffff 2000
# no data for 8003fffffffffff 2005
# no data for 8003fffffffffff 2010
# no data for 8003fffffffffff 2015
# no data for 8003fffffffffff 2020
# no data for 8003fffffffffff 2025
# no data for 8005fffffffffff 1975
# no data for 8005fffffffffff 1980
# no data for 8005fffffffffff 1985
# no data for 8005fffffffffff 1990
# no data for 8005fffffffffff 1995
# no data for 8005fffffffffff 2000
# no data for 8005fffffffffff 2005
# no data for 8005fffffffffff 2010
# no data for 8005fffffffffff 2015
# no data for 8005fffffffffff 2020
# no data for 8005fffffffffff 2025
# no data for 8007fffffffffff 1975
# no data for 8007fffffffffff 1980
# no data for 8007fffffffffff 1985
# no data for 8007fffffffffff 1990
# no data for 8007fffffffffff 1995
# no data for 8007fffffffffff 2000
# no data for 8007fffffffffff 2005
# no data for 8007fffffffffff 2010
# no data for 8007fffffffffff 2015
# no data for 8007fffffffffff 2020
# no data for 8007fffffffffff 2025
# no data for 8009fffffffffff 1975
# no data for 8009fffffffffff 1980
# no data for 8009fffffffffff 1985
# no data for 8009fffffffffff 1990
# no data for 8009fffffffffff 1995
# no data for 8009fffffffffff 2000
# no data for 8009fffffffffff 2005
# no data for 8009fffffffffff 2010
# no data for 8009fffffffffff 2015
# no data for 8009fffffffffff 2020
# no data for 8009fffffffffff 2025
# no data for 800bfffffffffff 1975
# no data for 800bfffffffffff 1980
# no data for 800bfffffffffff 1985
# no data for 800bfffffffffff 1990
# no data for 800bfffffffffff 1995
# no data for 800bfffffffffff 2000
# no data for 800bfffffffffff 2005
# no data for 800bfffffffffff 2010
# no data for 800bfffffffffff 2015
# no data for 800bfffffffffff 2020
# no data for 800bfffffffffff 2025
# no data for 800dfffffffffff 1975
# no data for 800dfffffffffff 1980
# no data for 800dfffffffffff 1985
# no data for 800dfffffffffff 1990
# no data for 800dfffffffffff 1995
# no data for 800dfffffffffff 2000
# no data for 800dfffffffffff 2005
# no data for 800dfffffffffff 2010
# no data for 800dfffffffffff 2015
# no data for 800dfffffffffff 2020
# no data for 800dfffffffffff 2025
# no data for 800ffffffffffff 1975
# no data for 800ffffffffffff 1980
# no data for 800ffffffffffff 1985
# no data for 800ffffffffffff 1990
# no data for 800ffffffffffff 1995
# no data for 800ffffffffffff 2000
# no data for 800ffffffffffff 2005
# no data for 800ffffffffffff 2010
# no data for 800ffffffffffff 2015
# no data for 800ffffffffffff 2020
# no data for 800ffffffffffff 2025
# no data for 8011fffffffffff 1975
# no data for 8011fffffffffff 1980
# no data for 8011fffffffffff 1985
# no data for 8011fffffffffff 1990
# no data for 8011fffffffffff 1995
# no data for 8011fffffffffff 2000
# no data for 8011fffffffffff 2005
# no data for 8011fffffffffff 2010
# no data for 8011fffffffffff 2015
# no data for 8011fffffffffff 2020
# no data for 8011fffffffffff 2025
# no data for 8013fffffffffff 1975
# no data for 8013fffffffffff 1980
# no data for 8013fffffffffff 1985
# no data for 8013fffffffffff 1990
# no data for 8013fffffffffff 1995
# no data for 8013fffffffffff 2000
# no data for 8013fffffffffff 2005
# no data for 8013fffffffffff 2010
# no data for 8013fffffffffff 2015
# no data for 8013fffffffffff 2020
# no data for 8013fffffffffff 2025
# no data for 8015fffffffffff 1975
# no data for 8015fffffffffff 1980
# no data for 8015fffffffffff 1985
# no data for 8015fffffffffff 1990
# no data for 8015fffffffffff 1995
# no data for 8015fffffffffff 2000
# no data for 8015fffffffffff 2005
# no data for 8015fffffffffff 2010
# no data for 8015fffffffffff 2015
# no data for 8015fffffffffff 2020
# no data for 8015fffffffffff 2025
# no data for 8017fffffffffff 1975
# no data for 8027fffffffffff 1995
# no data for 8027fffffffffff 2000
# no data for 8027fffffffffff 2005
# no data for 8027fffffffffff 2010
# no data for 8027fffffffffff 2015
# no data for 8027fffffffffff 2020
# no data for 8027fffffffffff 2025
# no data for 8029fffffffffff 1975
# no data for 8029fffffffffff 1980
# no data for 8029fffffffffff 1985
# no data for 8029fffffffffff 1990
# no data for 8029fffffffffff 1995
# no data for 8029fffffffffff 2000
# no data for 8029fffffffffff 2005
# no data for 8029fffffffffff 2010
# no data for 8029fffffffffff 2015
# no data for 8029fffffffffff 2020
# no data for 8029fffffffffff 2025
# no data for 802bfffffffffff 1975
# no data for 802bfffffffffff 1980
# no data for 802bfffffffffff 1985
# no data for 802bfffffffffff 1990
# no data for 802bfffffffffff 1995
# no data for 802bfffffffffff 2000
# no data for 802bfffffffffff 2005
# no data for 802bfffffffffff 2010
# no data for 802bfffffffffff 2015
# no data for 802bfffffffffff 2020
# no data for 802bfffffffffff 2025
# no data for 802dfffffffffff 1975
# no data for 802dfffffffffff 1980
# no data for 802dfffffffffff 1985
# no data for 802dfffffffffff 1990
# no data for 802dfffffffffff 1995
# no data for 802dfffffffffff 2000
# no data for 802dfffffffffff 2005
# no data for 802dfffffffffff 2010
# no data for 802dfffffffffff 2015
# no data for 802dfffffffffff 2020
# no data for 802dfffffffffff 2025
# no data for 802ffffffffffff 1975
# no data for 802ffffffffffff 1980
# no data for 802ffffffffffff 1985
# no data for 802ffffffffffff 1990
# no data for 802ffffffffffff 1995
# no data for 802ffffffffffff 2000
# no data for 802ffffffffffff 2005
# no data for 802ffffffffffff 2010
# no data for 802ffffffffffff 2015
# no data for 802ffffffffffff 2020
# no data for 802ffffffffffff 2025
# no data for 8031fffffffffff 1975
# no data for 8031fffffffffff 1980
# no data for 8031fffffffffff 1985
# no data for 8031fffffffffff 1990
# no data for 8031fffffffffff 1995
# no data for 8031fffffffffff 2000
# no data for 8031fffffffffff 2005
# no data for 8031fffffffffff 2010
# no data for 8031fffffffffff 2015
# no data for 8031fffffffffff 2020
# no data for 8031fffffffffff 2025
# no data for 8033fffffffffff 1975
# no data for 8033fffffffffff 1980
# no data for 8033fffffffffff 1985
# no data for 8033fffffffffff 1990
# no data for 8033fffffffffff 1995
# no data for 8033fffffffffff 2000
# no data for 8033fffffffffff 2005
# no data for 8033fffffffffff 2010
# no data for 8033fffffffffff 2015
# no data for 8033fffffffffff 2020
# no data for 8033fffffffffff 2025
# no data for 8035fffffffffff 1975
# no data for 8035fffffffffff 1980
# no data for 8035fffffffffff 1985
# no data for 8035fffffffffff 1990
# no data for 8035fffffffffff 1995
# no data for 8035fffffffffff 2000
# no data for 8035fffffffffff 2005
# no data for 8035fffffffffff 2010
# no data for 8035fffffffffff 2015
# no data for 8035fffffffffff 2020
# no data for 8035fffffffffff 2025
# no data for 8039fffffffffff 1975
# no data for 8039fffffffffff 1980
# no data for 8039fffffffffff 1985
# no data for 8039fffffffffff 1990
# no data for 8039fffffffffff 1995
# no data for 8039fffffffffff 2000
# no data for 8039fffffffffff 2005
# no data for 8039fffffffffff 2010
# no data for 804dfffffffffff 1975
# no data for 804dfffffffffff 1980
# no data for 804dfffffffffff 1985
# no data for 804dfffffffffff 1990
# no data for 804dfffffffffff 1995
# no data for 804dfffffffffff 2000
# no data for 804dfffffffffff 2005
# no data for 804dfffffffffff 2010
# no data for 804dfffffffffff 2015
# no data for 804dfffffffffff 2020
# no data for 804dfffffffffff 2025
# no data for 804ffffffffffff 1975
# no data for 804ffffffffffff 1980
# no data for 804ffffffffffff 1985
# no data for 804ffffffffffff 1990
# no data for 804ffffffffffff 1995
# no data for 804ffffffffffff 2000
# no data for 804ffffffffffff 2005
# no data for 804ffffffffffff 2010
# no data for 804ffffffffffff 2015
# no data for 804ffffffffffff 2020
# no data for 804ffffffffffff 2025
# no data for 8053fffffffffff 1975
# no data for 8053fffffffffff 1980
# no data for 8053fffffffffff 1985
# no data for 8053fffffffffff 1990
# no data for 8053fffffffffff 1995
# no data for 8053fffffffffff 2000
# no data for 8053fffffffffff 2005
# no data for 8053fffffffffff 2010
# no data for 8053fffffffffff 2015
# no data for 8053fffffffffff 2020
# no data for 8053fffffffffff 2025
# no data for 8055fffffffffff 1975
# no data for 8055fffffffffff 1980
# no data for 8055fffffffffff 1985
# no data for 8055fffffffffff 1990
# no data for 8055fffffffffff 1995
# no data for 8055fffffffffff 2000
# no data for 8055fffffffffff 2005
# no data for 8055fffffffffff 2010
# no data for 8055fffffffffff 2015
# no data for 8055fffffffffff 2020
# no data for 8055fffffffffff 2025
# no data for 8057fffffffffff 1975
# no data for 8057fffffffffff 1980
# no data for 8057fffffffffff 1985
# no data for 8057fffffffffff 1990
# no data for 8057fffffffffff 1995
# no data for 8057fffffffffff 2000
# no data for 8057fffffffffff 2005
# no data for 8057fffffffffff 2010
# no data for 8057fffffffffff 2015
# no data for 8057fffffffffff 2020
# no data for 8057fffffffffff 2025
# no data for 8059fffffffffff 1975
# no data for 8059fffffffffff 1980
# no data for 8059fffffffffff 1985
# no data for 8059fffffffffff 1990
# no data for 8059fffffffffff 1995
# no data for 8059fffffffffff 2000
# no data for 8059fffffffffff 2005
# no data for 8059fffffffffff 2010
# no data for 8059fffffffffff 2015
# no data for 8059fffffffffff 2020
# no data for 8059fffffffffff 2025
# no data for 805bfffffffffff 1975
# no data for 805bfffffffffff 1980
# no data for 805bfffffffffff 1985
# no data for 805bfffffffffff 1990
# no data for 805bfffffffffff 1995
# no data for 805bfffffffffff 2000
# no data for 805bfffffffffff 2005
# no data for 805bfffffffffff 2010
# no data for 805bfffffffffff 2015
# no data for 805bfffffffffff 2020
# no data for 805bfffffffffff 2025
# no data for 805dfffffffffff 1975
# no data for 805dfffffffffff 1980
# no data for 805dfffffffffff 1985
# no data for 805dfffffffffff 1990
# no data for 805dfffffffffff 1995
# no data for 805dfffffffffff 2000
# no data for 805dfffffffffff 2005
# no data for 805dfffffffffff 2010
# no data for 805dfffffffffff 2015
# no data for 805dfffffffffff 2020
# no data for 805dfffffffffff 2025
# no data for 805ffffffffffff 1975
# no data for 805ffffffffffff 1980
# no data for 805ffffffffffff 1985
# no data for 805ffffffffffff 1990
# no data for 805ffffffffffff 1995
# no data for 805ffffffffffff 2000
# no data for 805ffffffffffff 2005
# no data for 805ffffffffffff 2010
# no data for 805ffffffffffff 2015
# no data for 805ffffffffffff 2020
# no data for 805ffffffffffff 2025
# no data for 8061fffffffffff 1975
# no data for 8061fffffffffff 1980
# no data for 8061fffffffffff 1985
# no data for 8061fffffffffff 1990
# no data for 8061fffffffffff 1995
# no data for 8061fffffffffff 2000
# no data for 8061fffffffffff 2005
# no data for 8061fffffffffff 2010
# no data for 8061fffffffffff 2015
# no data for 8061fffffffffff 2020
# no data for 8061fffffffffff 2025
# no data for 8063fffffffffff 1975
# no data for 8063fffffffffff 1980
# no data for 8063fffffffffff 1985
# no data for 8063fffffffffff 1990
# no data for 8063fffffffffff 1995
# no data for 8063fffffffffff 2000
# no data for 8063fffffffffff 2005
# no data for 8063fffffffffff 2010
# no data for 8063fffffffffff 2015
# no data for 8063fffffffffff 2020
# no data for 8063fffffffffff 2025
# no data for 8065fffffffffff 1975
# no data for 8065fffffffffff 1980
# no data for 8065fffffffffff 1985
# no data for 8065fffffffffff 1990
# no data for 8065fffffffffff 1995
# no data for 8065fffffffffff 2000
# no data for 8065fffffffffff 2005
# no data for 8065fffffffffff 2010
# no data for 8065fffffffffff 2015
# no data for 8065fffffffffff 2020
# no data for 8065fffffffffff 2025
# no data for 8067fffffffffff 1975
# no data for 8067fffffffffff 1980
# no data for 8067fffffffffff 1985
# no data for 8067fffffffffff 1990
# no data for 8067fffffffffff 1995
# no data for 8067fffffffffff 2000
# no data for 8067fffffffffff 2005
# no data for 8067fffffffffff 2010
# no data for 8067fffffffffff 2015
# no data for 8067fffffffffff 2020
# no data for 8067fffffffffff 2025
# no data for 8069fffffffffff 1975
# no data for 8069fffffffffff 1980
# no data for 8069fffffffffff 1985
# no data for 8069fffffffffff 1990
# no data for 8069fffffffffff 1995
# no data for 8069fffffffffff 2000
# no data for 8069fffffffffff 2005
# no data for 8069fffffffffff 2010
# no data for 8069fffffffffff 2015
# no data for 8069fffffffffff 2020
# no data for 8069fffffffffff 2025
# no data for 806bfffffffffff 1975
# no data for 806bfffffffffff 1980
# no data for 806bfffffffffff 1985
# no data for 806bfffffffffff 1990
# no data for 806bfffffffffff 1995
# no data for 806bfffffffffff 2000
# no data for 806bfffffffffff 2005
# no data for 806bfffffffffff 2010
# no data for 806bfffffffffff 2015
# no data for 806bfffffffffff 2020
# no data for 806bfffffffffff 2025
# no data for 806dfffffffffff 1975
# no data for 806dfffffffffff 1980
# no data for 806dfffffffffff 1985
# no data for 806dfffffffffff 1990
# no data for 806dfffffffffff 1995
# no data for 806dfffffffffff 2000
# no data for 806dfffffffffff 2005
# no data for 806dfffffffffff 2010
# no data for 806dfffffffffff 2015
# no data for 806dfffffffffff 2020
# no data for 806dfffffffffff 2025
# no data for 806ffffffffffff 1975
# no data for 806ffffffffffff 1980
# no data for 806ffffffffffff 1985
# no data for 806ffffffffffff 1990
# no data for 806ffffffffffff 1995
# no data for 806ffffffffffff 2000
# no data for 806ffffffffffff 2005
# no data for 806ffffffffffff 2010
# no data for 806ffffffffffff 2015
# no data for 806ffffffffffff 2020
# no data for 806ffffffffffff 2025
# no data for 8071fffffffffff 1975
# no data for 8071fffffffffff 1980
# no data for 8071fffffffffff 1985
# no data for 8071fffffffffff 1990
# no data for 8071fffffffffff 1995
# no data for 8071fffffffffff 2000
# no data for 8071fffffffffff 2005
# no data for 8071fffffffffff 2010
# no data for 8071fffffffffff 2015
# no data for 8071fffffffffff 2020
# no data for 8071fffffffffff 2025
# no data for 8073fffffffffff 1975
# no data for 8073fffffffffff 1980
# no data for 8073fffffffffff 1985
# no data for 8073fffffffffff 1990
# no data for 8073fffffffffff 1995
# no data for 8073fffffffffff 2000
# no data for 8073fffffffffff 2005
# no data for 8073fffffffffff 2010
# no data for 8073fffffffffff 2015
# no data for 8073fffffffffff 2020
# no data for 8073fffffffffff 2025
# no data for 8075fffffffffff 1975
# no data for 8075fffffffffff 1980
# no data for 8075fffffffffff 1985
# no data for 8075fffffffffff 1990
# no data for 8075fffffffffff 1995
# no data for 8075fffffffffff 2000
# no data for 8075fffffffffff 2005
# no data for 8075fffffffffff 2010
# no data for 8075fffffffffff 2015
# no data for 8075fffffffffff 2020
# no data for 8075fffffffffff 2025
# no data for 8077fffffffffff 1975
# no data for 8077fffffffffff 1980
# no data for 8077fffffffffff 1985
# no data for 8077fffffffffff 1990
# no data for 8077fffffffffff 1995
# no data for 8077fffffffffff 2000
# no data for 8077fffffffffff 2005
# no data for 8077fffffffffff 2010
# no data for 8077fffffffffff 2015
# no data for 8077fffffffffff 2020
# no data for 8077fffffffffff 2025
# no data for 8079fffffffffff 1975
# no data for 8079fffffffffff 1980
# no data for 8079fffffffffff 1985
# no data for 8079fffffffffff 1990
# no data for 8079fffffffffff 1995
# no data for 8079fffffffffff 2000
# no data for 8079fffffffffff 2005
# no data for 8079fffffffffff 2010
# no data for 8079fffffffffff 2015
# no data for 8079fffffffffff 2020
# no data for 8079fffffffffff 2025
# no data for 807bfffffffffff 1975
# no data for 807bfffffffffff 1980
# no data for 807bfffffffffff 1985
# no data for 807bfffffffffff 1990
# no data for 807bfffffffffff 1995
# no data for 807bfffffffffff 2000
# no data for 807bfffffffffff 2005
# no data for 807bfffffffffff 2010
# no data for 807bfffffffffff 2015
# no data for 807bfffffffffff 2020
# no data for 807bfffffffffff 2025
# no data for 807dfffffffffff 1975
# no data for 807dfffffffffff 1980
# no data for 807dfffffffffff 1985
# no data for 807dfffffffffff 1990
# no data for 807dfffffffffff 1995
# no data for 807dfffffffffff 2000
# no data for 807dfffffffffff 2005
# no data for 807dfffffffffff 2010
# no data for 807dfffffffffff 2015
# no data for 807dfffffffffff 2020
# no data for 807dfffffffffff 2025
# no data for 807ffffffffffff 1975
# no data for 807ffffffffffff 1980
# no data for 807ffffffffffff 1985
# no data for 807ffffffffffff 1990
# no data for 807ffffffffffff 1995
# no data for 807ffffffffffff 2000
# no data for 807ffffffffffff 2005
# no data for 807ffffffffffff 2010
# no data for 807ffffffffffff 2015
# no data for 807ffffffffffff 2020
# no data for 807ffffffffffff 2025
# no data for 8081fffffffffff 1975
# no data for 8081fffffffffff 1980
# no data for 8081fffffffffff 1985
# no data for 8081fffffffffff 1990
# no data for 8081fffffffffff 1995
# no data for 8081fffffffffff 2000
# no data for 8081fffffffffff 2005
# no data for 8081fffffffffff 2010
# no data for 8081fffffffffff 2015
# no data for 8081fffffffffff 2020
# no data for 8081fffffffffff 2025
# no data for 8083fffffffffff 1975
# no data for 8083fffffffffff 1980
# no data for 8083fffffffffff 1985
# no data for 8083fffffffffff 1990
# no data for 8083fffffffffff 1995
# no data for 8083fffffffffff 2000
# no data for 8083fffffffffff 2005
# no data for 8083fffffffffff 2010
# no data for 8083fffffffffff 2015
# no data for 8083fffffffffff 2020
# no data for 8083fffffffffff 2025
# no data for 8085fffffffffff 1975
# no data for 8085fffffffffff 1980
# no data for 8085fffffffffff 1985
# no data for 8085fffffffffff 1990
# no data for 8085fffffffffff 1995
# no data for 8085fffffffffff 2000
# no data for 8085fffffffffff 2005
# no data for 8085fffffffffff 2010
# no data for 8085fffffffffff 2015
# no data for 8085fffffffffff 2020
# no data for 8085fffffffffff 2025
# no data for 8089fffffffffff 1975
# no data for 8089fffffffffff 1980
# no data for 8089fffffffffff 1985
# no data for 8089fffffffffff 1990
# no data for 8089fffffffffff 1995
# no data for 8089fffffffffff 2000
# no data for 8089fffffffffff 2005
# no data for 8089fffffffffff 2010
# no data for 8089fffffffffff 2015
# no data for 8089fffffffffff 2020
# no data for 8089fffffffffff 2025
# no data for 808bfffffffffff 1975
# no data for 808bfffffffffff 1980
# no data for 808bfffffffffff 1985
# no data for 808bfffffffffff 1990
# no data for 808bfffffffffff 1995
# no data for 808bfffffffffff 2000
# no data for 808bfffffffffff 2005
# no data for 808bfffffffffff 2010
# no data for 808bfffffffffff 2015
# no data for 808bfffffffffff 2020
# no data for 808bfffffffffff 2025
# no data for 808dfffffffffff 1975
# no data for 808dfffffffffff 1980
# no data for 808dfffffffffff 1985
# no data for 808dfffffffffff 1990
# no data for 808dfffffffffff 1995
# no data for 808dfffffffffff 2000
# no data for 808dfffffffffff 2005
# no data for 808dfffffffffff 2010
# no data for 808dfffffffffff 2015
# no data for 808dfffffffffff 2020
# no data for 808dfffffffffff 2025
# no data for 808ffffffffffff 1975
# no data for 808ffffffffffff 1980
# no data for 808ffffffffffff 1985
# no data for 808ffffffffffff 1990
# no data for 808ffffffffffff 1995
# no data for 808ffffffffffff 2000
# no data for 808ffffffffffff 2005
# no data for 808ffffffffffff 2010
# no data for 808ffffffffffff 2015
# no data for 808ffffffffffff 2020
# no data for 808ffffffffffff 2025
# no data for 8095fffffffffff 1975
# no data for 8095fffffffffff 1980
# no data for 8095fffffffffff 1985
# no data for 8095fffffffffff 1990
# no data for 8095fffffffffff 1995
# no data for 8095fffffffffff 2000
# no data for 8095fffffffffff 2005
# no data for 8095fffffffffff 2010
# no data for 8095fffffffffff 2015
# no data for 8095fffffffffff 2020
# no data for 8095fffffffffff 2025
# no data for 8097fffffffffff 1975
# no data for 80a7fffffffffff 1985
# no data for 80a7fffffffffff 1990
# no data for 80a7fffffffffff 1995
# no data for 80a7fffffffffff 2000
# no data for 80a7fffffffffff 2005
# no data for 80a7fffffffffff 2010
# no data for 80a7fffffffffff 2015
# no data for 80a7fffffffffff 2020
# no data for 80a7fffffffffff 2025
# no data for 80a9fffffffffff 1975
# no data for 80a9fffffffffff 1980
# no data for 80a9fffffffffff 1985
# no data for 80a9fffffffffff 1990
# no data for 80a9fffffffffff 1995
# no data for 80a9fffffffffff 2000
# no data for 80a9fffffffffff 2005
# no data for 80a9fffffffffff 2010
# no data for 80a9fffffffffff 2015
# no data for 80a9fffffffffff 2020
# no data for 80a9fffffffffff 2025
# no data for 80abfffffffffff 1975
# no data for 80abfffffffffff 1980
# no data for 80abfffffffffff 1985
# no data for 80abfffffffffff 1990
# no data for 80abfffffffffff 1995
# no data for 80abfffffffffff 2000
# no data for 80abfffffffffff 2005
# no data for 80abfffffffffff 2010
# no data for 80abfffffffffff 2015
# no data for 80abfffffffffff 2020
# no data for 80abfffffffffff 2025
# no data for 80adfffffffffff 1975
# no data for 80adfffffffffff 1980
# no data for 80adfffffffffff 1985
# no data for 80adfffffffffff 1990
# no data for 80adfffffffffff 1995
# no data for 80adfffffffffff 2000
# no data for 80adfffffffffff 2005
# no data for 80adfffffffffff 2010
# no data for 80adfffffffffff 2015
# no data for 80adfffffffffff 2020
# no data for 80adfffffffffff 2025
# no data for 80b1fffffffffff 1975
# no data for 80b1fffffffffff 1980
# no data for 80b1fffffffffff 1985
# no data for 80b1fffffffffff 1990
# no data for 80b1fffffffffff 1995
# no data for 80b1fffffffffff 2000
# no data for 80b1fffffffffff 2005
# no data for 80b1fffffffffff 2010
# no data for 80b1fffffffffff 2015
# no data for 80b1fffffffffff 2020
# no data for 80b1fffffffffff 2025
# no data for 80b3fffffffffff 1975
# no data for 80b3fffffffffff 1980
# no data for 80b3fffffffffff 1985
# no data for 80b3fffffffffff 1990
# no data for 80b3fffffffffff 1995
# no data for 80b3fffffffffff 2000
# no data for 80b3fffffffffff 2005
# no data for 80b3fffffffffff 2010
# no data for 80b3fffffffffff 2015
# no data for 80b3fffffffffff 2020
# no data for 80b3fffffffffff 2025
# no data for 80b5fffffffffff 1975
# no data for 80b5fffffffffff 1980
# no data for 80b5fffffffffff 1985
# no data for 80b5fffffffffff 1990
# no data for 80b5fffffffffff 1995
# no data for 80b5fffffffffff 2000
# no data for 80b5fffffffffff 2005
# no data for 80b5fffffffffff 2010
# no data for 80b5fffffffffff 2015
# no data for 80b5fffffffffff 2020
# no data for 80b5fffffffffff 2025
# no data for 80b9fffffffffff 1975
# no data for 80b9fffffffffff 1980
# no data for 80b9fffffffffff 1985
# no data for 80b9fffffffffff 1990
# no data for 80b9fffffffffff 1995
# no data for 80b9fffffffffff 2000
# no data for 80b9fffffffffff 2005
# no data for 80b9fffffffffff 2010
# no data for 80b9fffffffffff 2015
# no data for 80b9fffffffffff 2020
# no data for 80b9fffffffffff 2025
# no data for 80bbfffffffffff 1975
# no data for 80bbfffffffffff 1980
# no data for 80bbfffffffffff 1985
# no data for 80bbfffffffffff 1990
# no data for 80bbfffffffffff 1995
# no data for 80bbfffffffffff 2000
# no data for 80bbfffffffffff 2005
# no data for 80bbfffffffffff 2010
# no data for 80bbfffffffffff 2015
# no data for 80bbfffffffffff 2020
# no data for 80bbfffffffffff 2025
# no data for 80bdfffffffffff 1975
# no data for 80bdfffffffffff 1980
# no data for 80bdfffffffffff 1985
# no data for 80bdfffffffffff 1990
# no data for 80bdfffffffffff 1995
# no data for 80bdfffffffffff 2000
# no data for 80bdfffffffffff 2005
# no data for 80bdfffffffffff 2010
# no data for 80bdfffffffffff 2015
# no data for 80bdfffffffffff 2020
# no data for 80bdfffffffffff 2025
# no data for 80bffffffffffff 1975
# no data for 80bffffffffffff 1980
# no data for 80bffffffffffff 1985
# no data for 80bffffffffffff 1990
# no data for 80bffffffffffff 1995
# no data for 80bffffffffffff 2000
# no data for 80bffffffffffff 2005
# no data for 80bffffffffffff 2010
# no data for 80bffffffffffff 2015
# no data for 80bffffffffffff 2020
# no data for 80bffffffffffff 2025
# no data for 80c1fffffffffff 1975
# no data for 80c1fffffffffff 1980
# no data for 80c1fffffffffff 1985
# no data for 80c1fffffffffff 1990
# no data for 80c1fffffffffff 1995
# no data for 80c1fffffffffff 2000
# no data for 80c1fffffffffff 2005
# no data for 80c1fffffffffff 2010
# no data for 80c1fffffffffff 2015
# no data for 80c1fffffffffff 2020
# no data for 80c1fffffffffff 2025
# no data for 80c3fffffffffff 1975
# no data for 80c3fffffffffff 1980
# no data for 80c3fffffffffff 1985
# no data for 80c3fffffffffff 1990
# no data for 80c3fffffffffff 1995
# no data for 80c3fffffffffff 2000
# no data for 80c3fffffffffff 2005
# no data for 80c3fffffffffff 2010
# no data for 80c3fffffffffff 2015
# no data for 80c3fffffffffff 2020
# no data for 80c3fffffffffff 2025
# no data for 80c9fffffffffff 1975
# no data for 80c9fffffffffff 1980
# no data for 80c9fffffffffff 1985
# no data for 80c9fffffffffff 1990
# no data for 80c9fffffffffff 1995
# no data for 80c9fffffffffff 2000
# no data for 80c9fffffffffff 2005
# no data for 80c9fffffffffff 2010
# no data for 80c9fffffffffff 2015
# no data for 80c9fffffffffff 2020
# no data for 80c9fffffffffff 2025
# no data for 80cbfffffffffff 1975
# no data for 80cbfffffffffff 1980
# no data for 80cbfffffffffff 1985
# no data for 80cbfffffffffff 1990
# no data for 80cbfffffffffff 1995
# no data for 80cbfffffffffff 2000
# no data for 80cbfffffffffff 2005
# no data for 80cbfffffffffff 2010
# no data for 80cbfffffffffff 2015
# no data for 80cbfffffffffff 2020
# no data for 80cbfffffffffff 2025
# no data for 80cdfffffffffff 1975
# no data for 80cdfffffffffff 1980
# no data for 80cdfffffffffff 1985
# no data for 80cdfffffffffff 1990
# no data for 80cdfffffffffff 1995
# no data for 80cdfffffffffff 2000
# no data for 80cdfffffffffff 2005
# no data for 80cdfffffffffff 2010
# no data for 80cdfffffffffff 2015
# no data for 80cdfffffffffff 2020
# no data for 80cdfffffffffff 2025
# no data for 80dffffffffffff 2025
# no data for 80e1fffffffffff 1975
# no data for 80e1fffffffffff 1980
# no data for 80e1fffffffffff 1985
# no data for 80e1fffffffffff 1990
# no data for 80e1fffffffffff 1995
# no data for 80e1fffffffffff 2000
# no data for 80e1fffffffffff 2005
# no data for 80e1fffffffffff 2010
# no data for 80e1fffffffffff 2015
# no data for 80e1fffffffffff 2020
# no data for 80e1fffffffffff 2025
# no data for 80ebfffffffffff 1975
# no data for 80ebfffffffffff 1980
# no data for 80ebfffffffffff 1985
# no data for 80ebfffffffffff 1990
# no data for 80ebfffffffffff 1995
# no data for 80ebfffffffffff 2000
# no data for 80ebfffffffffff 2005
# no data for 80ebfffffffffff 2010
# no data for 80ebfffffffffff 2015
# no data for 80ebfffffffffff 2020
# no data for 80ebfffffffffff 2025

# %% [markdown]
# # Run test zonal stats

# %%
h3_level = 6
ghsl_folder = "C:/WBG/Work/data/GHSL"
ghsl_files = [os.path.join(ghsl_folder, f) for f in os.listdir(ghsl_folder) if f.endswith(".tif")]
out_folder = "C:/WBG/Work/S2S/data/GHSL"

# %%
h3_0_list = h3_helper.generate_lvl0_lists(h3_level, return_gdf=True, buffer0=False, 
                read_pickle=True, pickle_file="h0_dictionary_of_h6_geodata_frames_land.pickle")
# Out:
# Loading pickle file h0_dictionary_of_h6_geodata_frames_land.pickle: it exists True

# %%
for h3_0_key, h6_list in h3_0_list.items():
    print(f"Processing {h3_0_key}: {len(h6_list)} hexes")

sample_h0 = '8007fffffffffff'
inH = h3_0_list[sample_h0]
# Out:
# Processing 8001fffffffffff: 10516 hexes
# Processing 8003fffffffffff: 37740 hexes
# Processing 8005fffffffffff: 51141 hexes
# Processing 8007fffffffffff: 51656 hexes
# Processing 8009fffffffffff: 39466 hexes
# Processing 800bfffffffffff: 114016 hexes
# Processing 800dfffffffffff: 59002 hexes
# Processing 800ffffffffffff: 69309 hexes
# Processing 8011fffffffffff: 110447 hexes
# Processing 8013fffffffffff: 111635 hexes
# Processing 8015fffffffffff: 109233 hexes
# Processing 8017fffffffffff: 30219 hexes
# Processing 8019fffffffffff: 18011 hexes
# Processing 801bfffffffffff: 9786 hexes
# Processing 801dfffffffffff: 44 hexes
# Processing 801ffffffffffff: 99411 hexes
# Processing 8021fffffffffff: 120228 hexes
# Processing 8023fffffffffff: 2973 hexes
# Processing 8025fffffffffff: 118630 hexes
# Processing 8027fffffffffff: 118168 hexes
# Processing 8029fffffffffff: 46609 hexes
# Processing 802bfffffffffff: 47178 hexes
# Processing 802dfffffffffff: 97535 hexes
# Processing 802ffffffffffff: 19039 hexes
# Processing 8031fffffffffff: 68036 hexes
# Processing 8033fffffffffff: 5043 hexes
# Processing 8035fffffffffff: 448 hexes
# Processing 8039fffffffffff: 87261 hexes
# Processing 803dfffffffffff: 113195 hexes
# Processing 803ffffffffffff: 88959 hexes
# Processing 8041fffffffffff: 99586 hexes
# Processing 8043fffffffffff: 83374 hexes
# Processing 8045fffffffffff: 41707 hexes
# Processing 8047fffffffffff: 2402 hexes
# Processing 8049fffffffffff: 58820 hexes
# Processing 804bfffffffffff: 4721 hexes
# Processing 804dfffffffffff: 3578 hexes
# Processing 804ffffffffffff: 87 hexes
# Processing 8053fffffffffff: 97708 hexes
# Processing 8055fffffffffff: 75385 hexes
# Processing 8057fffffffffff: 93 hexes
# Processing 8059fffffffffff: 116983 hexes
# Processing 805bfffffffffff: 7352 hexes
# Processing 805dfffffffffff: 376 hexes
# Processing 805ffffffffffff: 28353 hexes
# Processing 8061fffffffffff: 27728 hexes
# Processing 8063fffffffffff: 4347 hexes
# Processing 8065fffffffffff: 37850 hexes
# Processing 8067fffffffffff: 56939 hexes
# Processing 8069fffffffffff: 30376 hexes
# Processing 806bfffffffffff: 119801 hexes
# Processing 806dfffffffffff: 11365 hexes
# Processing 806ffffffffffff: 2 hexes
# Processing 8071fffffffffff: 2989 hexes
# Processing 8073fffffffffff: 11770 hexes
# Processing 8075fffffffffff: 26248 hexes
# Processing 8077fffffffffff: 1497 hexes
# Processing 8079fffffffffff: 7 hexes
# Processing 807bfffffffffff: 50593 hexes
# Processing 807dfffffffffff: 1 hexes
# Processing 807ffffffffffff: 4126 hexes
# Processing 8081fffffffffff: 62124 hexes
# Processing 8083fffffffffff: 51049 hexes
# Processing 8085fffffffffff: 95 hexes
# Processing 8089fffffffffff: 174 hexes
# Processing 808bfffffffffff: 118664 hexes
# Processing 808dfffffffffff: 13888 hexes
# Processing 808ffffffffffff: 24149 hexes
# Processing 8095fffffffffff: 35151 hexes
# Processing 8097fffffffffff: 115007 hexes
# Processing 8099fffffffffff: 17 hexes
# Processing 809bfffffffffff: 4953 hexes
# Processing 809dfffffffffff: 50486 hexes
# Processing 809ffffffffffff: 1831 hexes
# Processing 80a1fffffffffff: 610 hexes
# Processing 80a3fffffffffff: 16541 hexes
# Processing 80a5fffffffffff: 323 hexes
# Processing 80a7fffffffffff: 29866 hexes
# Processing 80a9fffffffffff: 83646 hexes
# Processing 80abfffffffffff: 8 hexes
# Processing 80adfffffffffff: 33382 hexes
# Processing 80b1fffffffffff: 13 hexes
# Processing 80b3fffffffffff: 63531 hexes
# Processing 80b5fffffffffff: 46 hexes
# Processing 80b9fffffffffff: 82603 hexes
# Processing 80bbfffffffffff: 6786 hexes
# Processing 80bdfffffffffff: 27647 hexes
# Processing 80bffffffffffff: 36836 hexes
# Processing 80c1fffffffffff: 15 hexes
# Processing 80c3fffffffffff: 38333 hexes
# Processing 80c9fffffffffff: 4206 hexes
# Processing 80cbfffffffffff: 30 hexes
# Processing 80cdfffffffffff: 46 hexes
# Processing 80cffffffffffff: 30961 hexes
# Processing 80d1fffffffffff: 5 hexes
# Processing 80d5fffffffffff: 33 hexes
# Processing 80d7fffffffffff: 29 hexes
# Processing 80d9fffffffffff: 136 hexes
# Processing 80dbfffffffffff: 4600 hexes
# Processing 80ddfffffffffff: 37 hexes
# Processing 80dffffffffffff: 3996 hexes
# Processing 80e1fffffffffff: 363 hexes
# Processing 80ebfffffffffff: 2 hexes

# %%
out_file = os.path.join(out_folder, f"{sample_h0}_ghsl_stats.csv")
zonal_res = global_zonal.zonal_stats_numerical(inH, 'shape_id', ghsl_files[0], out_file, minVal=0, maxVal=100000)
zonal_res[out_file].max(skipna=True)
# Out:
# SUM             2549965
# MIN                   0
# MAX                8792
# MEAN         787.026235
# id      8607b67b7ffffff
# dtype: object

# %%
# Write h3 cells and clipped GHSL data to file
temp_folder = os.path.join(out_folder, "temp")
if not os.path.exists(temp_folder):
    os.makedirs(temp_folder)

temp_h3_file = os.path.join(temp_folder, f"{sample_h0}_h3.shp")
if not os.path.exists(temp_h3_file):
    inH.to_file(temp_h3_file)

temp_ghsl_file = os.path.join(temp_folder, f"{sample_h0}_ghsl.tif")
if not os.path.exists(temp_ghsl_file):
    rMisc.clipRaster(ghsl_files[0], inH, temp_ghsl_file)

# %%
sel_h6_id = '86075d8b7ffffff'
res = zonal_res[out_file]
res.loc[res['id'] == sel_h6_id]
# Out:
#         SUM   MIN   MAX  MEAN               id
# 38111  None  None  None  None  86075d8b7ffffff

# %%
m = s2s_gdf.explore(
    column=s2s_field[0],
    tooltip=s2s_field,
    cmap='YlGnBu',
    legend=True,
    scheme='naturalbreaks',
    legend_kwds=dict(colorbar=True, caption='Population', interval=False),
    style_kwds=dict(weight=0, fillOpacity=0.8),
    name='Population by Hexagon'
)
flm.LayerControl('topright', collapsed = False).add_to(m)
m

# %% [markdown]
# ## Assess s3 csv file

# %%
s2s_df['h1'] = s2s_df['hex_id'].apply(lambda x: h3.cell_to_parent(x, 0))
for unq_h1 in s2s_df['h1'].unique():
    s3_file = s3_csv_base.format(h1=unq_h1)
    curD = pd.read_csv(s3_file, index_col=0)
curD.head()

# %%
def get_geom(x):
    xx = h3.cell_to_latlng(x)
    return(Point([xx[1], xx[0]]))
curD = curD.reset_index()
curD = curD.merge(s2s_gdf, left_on="id", right_on="hex_id", how='right')
curD = gpd.GeoDataFrame(curD, geometry='geometry', crs=4326).reset_index()

# %%
m = curD.explore(
    column=s2s_field,
    tooltip=s2s_field,
    cmap='YlGnBu',
    legend=True,
    scheme='naturalbreaks',
    legend_kwds=dict(colorbar=True, caption='Population', interval=False),
    style_kwds=dict(weight=0, fillOpacity=0.8),
    name='Population by Hexagon'
)
flm.LayerControl('topright', collapsed = False).add_to(m)
m

# %% [markdown]
# ## From S3 Parquet

# %%
gdf = pd.read_parquet(s3_parquet_file)
gdf = gdf.reset_index()
gdf_columns = list(gdf.columns)
gdf_columns

# %%
gdf_columns[0] = 'hex_id'
gdf.columns = gdf_columns
gdf.to_parquet(s3_parquet_file, index=False)

# %%
gdf_s3 = gdf.merge(curD, left_on='hex_id', right_on='id', how='right')
gdf_s3 = gpd.GeoDataFrame(gdf_s3, geometry='geometry', crs=4326)
gdf_s3.head()

# %%
m = gdf_s3.explore(
    column=s2s_field,
    tooltip=s2s_field,
    cmap='YlGnBu',
    legend=True,
    scheme='naturalbreaks',
    legend_kwds=dict(colorbar=True, caption='Population', interval=False),
    style_kwds=dict(weight=0, fillOpacity=0.8),
    name='Population by Hexagon'
)
flm.LayerControl('topright', collapsed = False).add_to(m)
m
