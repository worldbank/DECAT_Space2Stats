# %% [markdown]
# # H3 zonal stats from a GeoTIFF to Parquet
#
# This notebook creates H3-based zonal statistics from a GeoTIFF and writes a Parquet file ready for ingestion (with a `hex_id` column and one or more metric columns).
#
# **Inputs**
# - GeoTIFF: `global-drought-spei-1.5-return-period-100-years.tiff`
#
# **Outputs**
# - CSV tiles (per H3 res-0 cell) in `data/drought_spei_1_5_rp100_h3_csv/`
# - Final Parquet in `data/drought_spei_1_5_rp100_mean.parquet`

# %% [markdown]
# ## 1) Configuration
# Adjust H3 resolution, output column names, and other options here.

# %%
# Parameters
TIF_PATH = "global-drought-spei-1.5-return-period-100-years.tiff"
H3_LEVEL = 6
OUT_CSV_DIR = "data/drought_spei_1_5_rp100_h3_csv"
OUT_PARQUET = "data/drought_spei_1_5_rp100_mean.parquet"

# Mask extreme nodata sentinels (e.g. float32 -3.4e38) to avoid overflow in SUM
ZONAL_MIN_VAL = -1e20
ZONAL_MAX_VAL = 1e20

# Choose output metric columns and names
# Options in the raw output: SUM, MIN, MAX, MEAN
OUTPUT_COLUMNS = {
    "MEAN": "drought_spei_1_5_rp100_mean",
}

# %% [markdown]
# ## 2) Imports and path setup
# We re-use the project utilities in `notebooks/src`.

# %%
import os
import sys
import glob
import pandas as pd

# Ensure project helpers are importable
sys.path.insert(0, "../../src")

import h3_helper
import global_zonal
import GOSTrocks

# %% [markdown]
# ## 3) Build H3 grid and run zonal stats
# Use the shared land-masked H3 grid pickle (res 6) for consistency across layers, then run zonal stats over the GeoTIFF.

# %%
import os
import io
import re
from contextlib import redirect_stdout

import h3
from shapely.geometry import box
import geopandas as gpd
import rasterio
import GOSTrocks.rasterMisc as rMisc
import pandas as pd

os.makedirs(OUT_CSV_DIR, exist_ok=True)

# Load canonical H3 grid (polygons in EPSG:4326)
h3_0_list = h3_helper.generate_lvl0_lists(
    H3_LEVEL,
    return_gdf=True,
    buffer0=True,
    read_pickle=True,
    pickle_file="h0_dictionary_of_h6_geodata_frames_land.pickle",
)

csv_files = []
items = list(h3_0_list.items())
total = len(items)

with rasterio.open(TIF_PATH) as src:
    rast_crs = src.crs
    rast_bounds = box(*src.bounds)

    for i, (h0_code, gdf) in enumerate(items, start=1):
        out_csv = os.path.join(OUT_CSV_DIR, f"drought_{h0_code}.csv")

        # Reproject ONCE for this chunk (4326 -> raster CRS)
        gdf_rast = gdf.to_crs(rast_crs)

        # Bounds filter in raster CRS
        mask = gdf_rast.intersects(rast_bounds)
        n = int(mask.sum())

        print(f"[{i:3d}/{total}] h0={h0_code} intersecting_hexes={n} csvs_written={len(csv_files)}", flush=True)

        if n == 0:
            continue

        # Select from the already-reprojected GeoDataFrame (no 2nd to_crs)
        gdf_sel_rast = gdf_rast.loc[mask.values].copy()

        # Zonal stats already in raster CRS -> reProj=False
        # Capture occasional per-feature failures reported as: "Error processing <n>"
        _buf = io.StringIO()
        with redirect_stdout(_buf):
            res = rMisc.zonalStats(
                gdf_sel_rast,
                TIF_PATH,
                reProj=False,
                minVal=ZONAL_MIN_VAL,
                maxVal=ZONAL_MAX_VAL,
            )
        failed_positions = {
            int(m.group(1))
            for m in re.finditer(r"Error processing\s+(\d+)", _buf.getvalue())
        }

        res = pd.DataFrame(res, columns=["SUM", "MIN", "MAX", "MEAN"])
        # shape_id should already be present from the pickle; if not, fallback:
        if "shape_id" in gdf_sel_rast.columns:
            ids = pd.Series(gdf_sel_rast["shape_id"].values)
        else:
            ids = pd.Series(gdf.loc[mask.values, "shape_id"].values)

        if failed_positions:
            bad_idx = [p - 1 for p in sorted(failed_positions) if p > 0]
            ids = ids.drop(index=bad_idx, errors="ignore").reset_index(drop=True)

        # Defensive fallback for any residual mismatch
        if len(ids) != len(res):
            n = min(len(ids), len(res))
            print(
                f"Warning: id/stat length mismatch for h0={h0_code} (ids={len(ids)}, stats={len(res)}). Truncating to {n}.",
                flush=True,
            )
            ids = ids.iloc[:n].reset_index(drop=True)
            res = res.iloc[:n].copy()

        res["id"] = ids.values

        res.to_csv(out_csv, index=False)
        csv_files.append(out_csv)

print(f"Done. Wrote {len(csv_files)} CSV files.", flush=True)
# Out:
# Loading pickle file h0_dictionary_of_h6_geodata_frames_land.pickle: it exists True
# [  1/122] h0=8001fffffffffff intersecting_hexes=117649 csvs_written=0
# [  2/122] h0=8003fffffffffff intersecting_hexes=117649 csvs_written=1
# [  3/122] h0=8005fffffffffff intersecting_hexes=117649 csvs_written=2
# [  4/122] h0=8007fffffffffff intersecting_hexes=117649 csvs_written=3
# [  5/122] h0=8009fffffffffff intersecting_hexes=98041 csvs_written=4
# [  6/122] h0=800bfffffffffff intersecting_hexes=117649 csvs_written=5
# [  7/122] h0=800dfffffffffff intersecting_hexes=117649 csvs_written=6
# [  8/122] h0=800ffffffffffff intersecting_hexes=117649 csvs_written=7
# [  9/122] h0=8011fffffffffff intersecting_hexes=117649 csvs_written=8
# [ 10/122] h0=8013fffffffffff intersecting_hexes=117649 csvs_written=9
# [ 11/122] h0=8015fffffffffff intersecting_hexes=117649 csvs_written=10
# [ 12/122] h0=8017fffffffffff intersecting_hexes=117649 csvs_written=11
# [ 13/122] h0=8019fffffffffff intersecting_hexes=117649 csvs_written=12
# [ 14/122] h0=801bfffffffffff intersecting_hexes=117649 csvs_written=13
# [ 15/122] h0=801dfffffffffff intersecting_hexes=98041 csvs_written=14
# [ 16/122] h0=801ffffffffffff intersecting_hexes=117649 csvs_written=15
# [ 17/122] h0=8021fffffffffff intersecting_hexes=117649 csvs_written=16
# [ 18/122] h0=8023fffffffffff intersecting_hexes=117649 csvs_written=17
# [ 19/122] h0=8025fffffffffff intersecting_hexes=117649 csvs_written=18
# [ 20/122] h0=8027fffffffffff intersecting_hexes=117649 csvs_written=19
# [ 21/122] h0=8029fffffffffff intersecting_hexes=117649 csvs_written=20
# [ 22/122] h0=802bfffffffffff intersecting_hexes=117649 csvs_written=21
# [ 23/122] h0=802dfffffffffff intersecting_hexes=117649 csvs_written=22
# [ 24/122] h0=802ffffffffffff intersecting_hexes=117649 csvs_written=23
# [ 25/122] h0=8031fffffffffff intersecting_hexes=98041 csvs_written=24
# [ 26/122] h0=8033fffffffffff intersecting_hexes=117649 csvs_written=25
# [ 27/122] h0=8035fffffffffff intersecting_hexes=117649 csvs_written=26
# [ 28/122] h0=8037fffffffffff intersecting_hexes=117649 csvs_written=27
# [ 29/122] h0=8039fffffffffff intersecting_hexes=117649 csvs_written=28
# [ 30/122] h0=803bfffffffffff intersecting_hexes=117649 csvs_written=29
# [ 31/122] h0=803dfffffffffff intersecting_hexes=117649 csvs_written=30
# [ 32/122] h0=803ffffffffffff intersecting_hexes=117649 csvs_written=31
# [ 33/122] h0=8041fffffffffff intersecting_hexes=117649 csvs_written=32
# [ 34/122] h0=8043fffffffffff intersecting_hexes=117649 csvs_written=33
# [ 35/122] h0=8045fffffffffff intersecting_hexes=117649 csvs_written=34
# [ 36/122] h0=8047fffffffffff intersecting_hexes=117649 csvs_written=35
# [ 37/122] h0=8049fffffffffff intersecting_hexes=117649 csvs_written=36
# [ 38/122] h0=804bfffffffffff intersecting_hexes=117649 csvs_written=37
# [ 39/122] h0=804dfffffffffff intersecting_hexes=98041 csvs_written=38
# [ 40/122] h0=804ffffffffffff intersecting_hexes=117649 csvs_written=39
# [ 41/122] h0=8051fffffffffff intersecting_hexes=117649 csvs_written=40
# [ 42/122] h0=8053fffffffffff intersecting_hexes=117649 csvs_written=41
# [ 43/122] h0=8055fffffffffff intersecting_hexes=117649 csvs_written=42
# [ 44/122] h0=8057fffffffffff intersecting_hexes=117649 csvs_written=43
# [ 45/122] h0=8059fffffffffff intersecting_hexes=117649 csvs_written=44
# [ 46/122] h0=805bfffffffffff intersecting_hexes=117649 csvs_written=45
# [ 47/122] h0=805dfffffffffff intersecting_hexes=117649 csvs_written=46
# [ 48/122] h0=805ffffffffffff intersecting_hexes=117649 csvs_written=47
# [ 49/122] h0=8061fffffffffff intersecting_hexes=117649 csvs_written=48
# [ 50/122] h0=8063fffffffffff intersecting_hexes=98041 csvs_written=49
# [ 51/122] h0=8065fffffffffff intersecting_hexes=117649 csvs_written=50
# [ 52/122] h0=8067fffffffffff intersecting_hexes=117649 csvs_written=51
# [ 53/122] h0=8069fffffffffff intersecting_hexes=117649 csvs_written=52
# [ 54/122] h0=806bfffffffffff intersecting_hexes=117649 csvs_written=53
# [ 55/122] h0=806dfffffffffff intersecting_hexes=117649 csvs_written=54
# [ 56/122] h0=806ffffffffffff intersecting_hexes=117649 csvs_written=55
# [ 57/122] h0=8071fffffffffff intersecting_hexes=117649 csvs_written=56
# [ 58/122] h0=8073fffffffffff intersecting_hexes=117649 csvs_written=57
# [ 59/122] h0=8075fffffffffff intersecting_hexes=98041 csvs_written=58
# [ 60/122] h0=8077fffffffffff intersecting_hexes=117649 csvs_written=59
# [ 61/122] h0=8079fffffffffff intersecting_hexes=117649 csvs_written=60
# [ 62/122] h0=807bfffffffffff intersecting_hexes=117649 csvs_written=61
# [ 63/122] h0=807dfffffffffff intersecting_hexes=117649 csvs_written=62
# [ 64/122] h0=807ffffffffffff intersecting_hexes=98041 csvs_written=63
# [ 65/122] h0=8081fffffffffff intersecting_hexes=117649 csvs_written=64
# [ 66/122] h0=8083fffffffffff intersecting_hexes=117649 csvs_written=65
# [ 67/122] h0=8085fffffffffff intersecting_hexes=117649 csvs_written=66
# [ 68/122] h0=8087fffffffffff intersecting_hexes=117649 csvs_written=67
# [ 69/122] h0=8089fffffffffff intersecting_hexes=117649 csvs_written=68
# [ 70/122] h0=808bfffffffffff intersecting_hexes=117649 csvs_written=69
# [ 71/122] h0=808dfffffffffff intersecting_hexes=117649 csvs_written=70
# [ 72/122] h0=808ffffffffffff intersecting_hexes=117649 csvs_written=71
# [ 73/122] h0=8091fffffffffff intersecting_hexes=98041 csvs_written=72
# [ 74/122] h0=8093fffffffffff intersecting_hexes=117649 csvs_written=73
# [ 75/122] h0=8095fffffffffff intersecting_hexes=117649 csvs_written=74
# [ 76/122] h0=8097fffffffffff intersecting_hexes=117649 csvs_written=75
# [ 77/122] h0=8099fffffffffff intersecting_hexes=117649 csvs_written=76
# [ 78/122] h0=809bfffffffffff intersecting_hexes=117649 csvs_written=77
# [ 79/122] h0=809dfffffffffff intersecting_hexes=117649 csvs_written=78
# [ 80/122] h0=809ffffffffffff intersecting_hexes=117649 csvs_written=79
# [ 81/122] h0=80a1fffffffffff intersecting_hexes=117649 csvs_written=80
# [ 82/122] h0=80a3fffffffffff intersecting_hexes=117649 csvs_written=81
# [ 83/122] h0=80a5fffffffffff intersecting_hexes=117649 csvs_written=82
# [ 84/122] h0=80a7fffffffffff intersecting_hexes=98041 csvs_written=83
# [ 85/122] h0=80a9fffffffffff intersecting_hexes=117649 csvs_written=84
# [ 86/122] h0=80abfffffffffff intersecting_hexes=117649 csvs_written=85
# [ 87/122] h0=80adfffffffffff intersecting_hexes=117649 csvs_written=86
# [ 88/122] h0=80affffffffffff intersecting_hexes=117649 csvs_written=87
# [ 89/122] h0=80b1fffffffffff intersecting_hexes=117649 csvs_written=88
# [ 90/122] h0=80b3fffffffffff intersecting_hexes=117649 csvs_written=89
# [ 91/122] h0=80b5fffffffffff intersecting_hexes=117649 csvs_written=90
# [ 92/122] h0=80b7fffffffffff intersecting_hexes=117649 csvs_written=91
# [ 93/122] h0=80b9fffffffffff intersecting_hexes=117649 csvs_written=92
# [ 94/122] h0=80bbfffffffffff intersecting_hexes=117649 csvs_written=93
# [ 95/122] h0=80bdfffffffffff intersecting_hexes=117649 csvs_written=94
# [ 96/122] h0=80bffffffffffff intersecting_hexes=117649 csvs_written=95
# [ 97/122] h0=80c1fffffffffff intersecting_hexes=117649 csvs_written=96
# [ 98/122] h0=80c3fffffffffff intersecting_hexes=98041 csvs_written=97
# [ 99/122] h0=80c5fffffffffff intersecting_hexes=117649 csvs_written=98
# [100/122] h0=80c7fffffffffff intersecting_hexes=117649 csvs_written=99
# [101/122] h0=80c9fffffffffff intersecting_hexes=117649 csvs_written=100
# [102/122] h0=80cbfffffffffff intersecting_hexes=117649 csvs_written=101
# [103/122] h0=80cdfffffffffff intersecting_hexes=117649 csvs_written=102
# [104/122] h0=80cffffffffffff intersecting_hexes=117649 csvs_written=103
# [105/122] h0=80d1fffffffffff intersecting_hexes=117649 csvs_written=104
# [106/122] h0=80d3fffffffffff intersecting_hexes=117649 csvs_written=105
# [107/122] h0=80d5fffffffffff intersecting_hexes=117649 csvs_written=106
# [108/122] h0=80d7fffffffffff intersecting_hexes=98041 csvs_written=107
# [109/122] h0=80d9fffffffffff intersecting_hexes=117649 csvs_written=108
# [110/122] h0=80dbfffffffffff intersecting_hexes=117649 csvs_written=109
# [111/122] h0=80ddfffffffffff intersecting_hexes=117649 csvs_written=110
# [112/122] h0=80dffffffffffff intersecting_hexes=117649 csvs_written=111
# [113/122] h0=80e1fffffffffff intersecting_hexes=117649 csvs_written=112
# [114/122] h0=80e3fffffffffff intersecting_hexes=117649 csvs_written=113
# [115/122] h0=80e5fffffffffff intersecting_hexes=117649 csvs_written=114
# [116/122] h0=80e7fffffffffff intersecting_hexes=117649 csvs_written=115
# [117/122] h0=80e9fffffffffff intersecting_hexes=117649 csvs_written=116
# [118/122] h0=80ebfffffffffff intersecting_hexes=98041 csvs_written=117
# [119/122] h0=80edfffffffffff intersecting_hexes=117649 csvs_written=118
# [120/122] h0=80effffffffffff intersecting_hexes=117649 csvs_written=119
# [121/122] h0=80f1fffffffffff intersecting_hexes=117649 csvs_written=120
# [122/122] h0=80f3fffffffffff intersecting_hexes=117649 csvs_written=121
# Done. Wrote 122 CSV files.

# %%
import os
print(os.getcwd())
# Out:
# /Users/glevin/Documents/WorldBank/Space2Stats/notebooks/MP_SCRIPTS/SPEI

# %% [markdown]
# ## 4) Combine CSVs and write Parquet
# The output parquet includes a `hex_id` column and the selected metric columns.

# %%
csvs = glob.glob(os.path.join(OUT_CSV_DIR, "*.csv"))
if not csvs:
    raise FileNotFoundError(f"No CSVs found in {OUT_CSV_DIR}")

df = pd.concat((pd.read_csv(c) for c in csvs), ignore_index=True)

# Rename id -> hex_id for ingestion compatibility
if "id" in df.columns:
    df = df.rename(columns={"id": "hex_id"})

# Select and rename output columns
keep_cols = ["hex_id"] + list(OUTPUT_COLUMNS.keys())
missing = [c for c in keep_cols if c not in df.columns]
if missing:
    raise ValueError(f"Missing expected columns from zonal stats: {missing}")

df = df[keep_cols].rename(columns=OUTPUT_COLUMNS)


# Write parquet
os.makedirs(os.path.dirname(OUT_PARQUET), exist_ok=True)

# keep hex_id as string, force metrics to float
for col in OUTPUT_COLUMNS.values():  # e.g. ["drought_spei_1_5_rp100_mean"]
    df[col] = pd.to_numeric(df[col], errors="coerce")
df.to_parquet(OUT_PARQUET, index=False)
OUT_PARQUET
# Out:
# 'data/drought_spei_1_5_rp100_mean.parquet'

# %% [markdown]
# ## 5) Quick sanity checks

# %%
df.head()

# %%
import pandas as pd
import geopandas as gpd
import h3
from shapely.geometry import Polygon
import folium
import branca.colormap as cm

PARQUET = "data/drought_spei_1_5_rp100_mean.parquet"
LEVEL = 6

# Read only required columns (faster)
df = pd.read_parquet(
    PARQUET,
    columns=["hex_id", "drought_spei_1_5_rp100_mean"],
)

# -----------------------
# Bounding box (min_lon, min_lat, max_lon, max_lat)
# Example East Africa bounding box (min_lon, min_lat, max_lon, max_lat)
bbox = (30.0, -5.0, 50.0, 15.0)
min_lon, min_lat, max_lon, max_lat = bbox

# H3 polyfill of bbox (h3 wants (lat, lon))
bbox_poly = h3.LatLngPoly(
    [
        (min_lat, min_lon),
        (min_lat, max_lon),
        (max_lat, max_lon),
        (max_lat, min_lon),
    ]
)

bbox_cells = set(h3.polygon_to_cells(bbox_poly, LEVEL))
df_bbox = df[df["hex_id"].isin(bbox_cells)].copy()

print("rows in bbox:", len(df_bbox))
print("bbox non-NaN rows:", df_bbox["drought_spei_1_5_rp100_mean"].notna().sum())

# Build polygons for ALL filtered hexes
def hex_to_poly(h):
    coords = h3.cell_to_boundary(h)  # (lat, lng)
    return Polygon([(lng, lat) for lat, lng in coords])

gdf_bbox = gpd.GeoDataFrame(
    df_bbox,
    geometry=[hex_to_poly(h) for h in df_bbox["hex_id"]],
    crs="EPSG:4326",
)

# A continuous colormap avoids the "bins" error from folium.Choropleth
# Data range used for display scaling
colormap = cm.linear.YlOrRd_09.scale(float(df["drought_spei_1_5_rp100_mean"].min()), float(df["drought_spei_1_5_rp100_mean"].max()))
colormap.caption = "Drought SPEI 1.5 RP100 (mean)"

center_lat = (min_lat + max_lat) / 2.0
center_lon = (min_lon + max_lon) / 2.0
m = folium.Map(location=[center_lat, center_lon], zoom_start=6, tiles="CartoDB positron")

def style_fn(feat):
    v = feat["properties"].get("drought_spei_1_5_rp100_mean", None)
    if v is None:
        return {"fillOpacity": 0.0, "weight": 0.0}
    v = float(v)
    return {
        "fillColor": colormap(v),
        "color": "#000000",
        "weight": 0.2,
        "fillOpacity": 0.7,
    }

folium.GeoJson(
    gdf_bbox,
    style_function=style_fn,
    tooltip=folium.GeoJsonTooltip(
        fields=["hex_id", "drought_spei_1_5_rp100_mean"],
        aliases=["hex_id", "drought_spei_1_5_rp100"],
        localize=True,
    ),
    name="hexes",
).add_to(m)

colormap.add_to(m)
folium.LayerControl().add_to(m)

m
